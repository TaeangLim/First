# %% [markdown]
# <a href="https://colab.research.google.com/github/TaeangLim/First/blob/main/Penguin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')
sns.set(font_scale=2.5) 
import missingno as msno

#ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
df_train = pd.read_csv('drive/MyDrive/pangdataset/train.csv')
df_test = pd.read_csv('drive/MyDrive/pangdataset/test.csv')

# %%
df_train.head(20)
# Out:
#     id  ... Body Mass (g)
# 0    0  ...          5550
# 1    1  ...          3800
# 2    2  ...          4400
# 3    3  ...          4850
# 4    4  ...          5700
# 5    5  ...          5250
# 6    6  ...          4250
# 7    7  ...          3450
# 8    8  ...          3475
# 9    9  ...          4750
# 10  10  ...          4550
# 11  11  ...          3300
# 12  12  ...          4850
# 13  13  ...          4700
# 14  14  ...          4050
# 15  15  ...          5000
# 16  16  ...          4400
# 17  17  ...          3075
# 18  18  ...          4650
# 19  19  ...          4250
#
# [20 rows x 11 columns]

# %%
df_train.describe()
# Out:
#                id  Culmen Length (mm)  ...  Delta 13 C (o/oo)  Body Mass (g)
# count  114.000000          114.000000  ...         111.000000     114.000000
# mean    56.500000           44.613158  ...         -25.723051    4327.850877
# std     33.052988            5.321829  ...           0.859786     781.766484
# min      0.000000           33.500000  ...         -27.018540    2700.000000
# 25%     28.250000           40.325000  ...         -26.434025    3675.000000
# 50%     56.500000           45.200000  ...         -25.955410    4250.000000
# 75%     84.750000           49.075000  ...         -25.005945    4850.000000
# max    113.000000           55.100000  ...         -24.102550    6300.000000
#
# [8 rows x 7 columns]

# %%
for col in df_train.columns:
    msg = 'column: {:>20}\t Percent of NaN value: {:.2f}%'.format(col, 100 * (df_train[col].isnull().sum() / df_train[col].shape[0]))
    print(msg)
# Out:
# column:                   id	 Percent of NaN value: 0.00%
# column:              Species	 Percent of NaN value: 0.00%
# column:               Island	 Percent of NaN value: 0.00%
# column:    Clutch Completion	 Percent of NaN value: 0.00%
# column:   Culmen Length (mm)	 Percent of NaN value: 0.00%
# column:    Culmen Depth (mm)	 Percent of NaN value: 0.00%
# column:  Flipper Length (mm)	 Percent of NaN value: 0.00%
# column:                  Sex	 Percent of NaN value: 2.63%
# column:    Delta 15 N (o/oo)	 Percent of NaN value: 2.63%
# column:    Delta 13 C (o/oo)	 Percent of NaN value: 2.63%
# column:        Body Mass (g)	 Percent of NaN value: 0.00%

# %%
for col in df_test.columns:
    msg = 'column: {:>20}\t Percent of NaN value: {:.2f}%'.format(col, 100 * (df_test[col].isnull().sum() / df_test[col].shape[0]))
    print(msg)
# Out:
# column:                   id	 Percent of NaN value: 0.00%
# column:              Species	 Percent of NaN value: 0.00%
# column:               Island	 Percent of NaN value: 0.00%
# column:    Clutch Completion	 Percent of NaN value: 0.00%
# column:   Culmen Length (mm)	 Percent of NaN value: 0.00%
# column:    Culmen Depth (mm)	 Percent of NaN value: 0.00%
# column:  Flipper Length (mm)	 Percent of NaN value: 0.00%
# column:                  Sex	 Percent of NaN value: 2.63%
# column:    Delta 15 N (o/oo)	 Percent of NaN value: 3.95%
# column:    Delta 13 C (o/oo)	 Percent of NaN value: 3.51%

# %%
msno.bar(df=df_train.iloc[:, :], figsize=(8, 8), color=(0.8, 0.5, 0.2))

# %%
df_train[['Species', 'Body Mass (g)']].groupby(['Species'], as_index=True).mean()
# Out:
#                                            Body Mass (g)
# Species
# Adelie Penguin (Pygoscelis adeliae)          3801.219512
# Chinstrap penguin (Pygoscelis antarctica)    3756.000000
# Gentoo penguin (Pygoscelis papua)            5075.520833

# %%
df_train[['Island', 'Body Mass (g)']].groupby(['Island'], as_index=True).mean()
# Out:
#            Body Mass (g)
# Island
# Biscoe       4878.947368
# Dream        3764.772727
# Torgersen    3817.307692

# %%
df_train[['Clutch Completion', 'Body Mass (g)']].groupby(['Clutch Completion'], as_index=True).mean()
# Out:
#                    Body Mass (g)
# Clutch Completion
# No                   4116.666667
# Yes                  4352.696078

# %%
df_train[['Culmen Length (mm)', 'Body Mass (g)']].groupby(['Culmen Length (mm)'], as_index=True).mean()
# Out:
#                     Body Mass (g)
# Culmen Length (mm)
# 33.5                       3600.0
# 34.0                       3400.0
# 34.1                       3475.0
# 35.3                       3800.0
# 35.5                       3350.0
# ...                           ...
# 52.8                       4550.0
# 53.4                       5500.0
# 53.5                       4500.0
# 54.3                       5650.0
# 55.1                       5850.0
#
# [87 rows x 1 columns]

# %%
df_train[['Culmen Depth (mm)', 'Body Mass (g)']].groupby(['Culmen Depth (mm)'], as_index=True).mean()
# Out:
#                    Body Mass (g)
# Culmen Depth (mm)
# 13.2                 4500.000000
# 13.3                 5100.000000
# 13.5                 4150.000000
# 13.9                 4900.000000
# 14.0                 4575.000000
# 14.1                 4412.500000
# 14.2                 4750.000000
# 14.4                 4525.000000
# 14.5                 4700.000000
# 14.6                 4762.500000
# 14.7                 4775.000000
# 14.8                 5200.000000
# 15.0                 4937.500000
# 15.2                 5475.000000
# 15.3                 5550.000000
# 15.4                 5050.000000
# 15.6                 5000.000000
# 15.7                 5400.000000
# 15.8                 5500.000000
# 15.9                 5450.000000
# 16.0                 5106.250000
# 16.1                 4550.000000
# 16.2                 3350.000000
# 16.3                 6000.000000
# 16.5                 4450.000000
# 16.6                 2700.000000
# 16.8                 3700.000000
# 16.9                 3000.000000
# 17.0                 4637.500000
# 17.1                 4066.666667
# 17.2                 3750.000000
# 17.3                 4129.166667
# 17.5                 3775.000000
# 17.6                 3800.000000
# 17.8                 3816.666667
# 17.9                 3808.333333
# 18.1                 3591.666667
# 18.2                 4225.000000
# 18.3                 3737.500000
# 18.4                 3900.000000
# 18.5                 3825.000000
# 18.6                 3733.333333
# 18.7                 3512.500000
# 18.8                 4025.000000
# 18.9                 3975.000000
# 19.0                 3875.000000
# 19.1                 4650.000000
# 19.3                 3300.000000
# 19.4                 3712.500000
# 19.5                 3883.333333
# 19.6                 4300.000000
# 19.9                 4500.000000
# 20.0                 4508.333333
# 20.2                 4250.000000
# 20.3                 3550.000000
# 20.5                 3775.000000
# 20.6                 3650.000000
# 21.1                 4150.000000

# %%
print('가장 긴 부리 길이 : {:.1f} (mm)'.format(df_train['Culmen Length (mm)'].max()))
print('가장 짧은 부리 길이 : {:.1f} (mm)'.format(df_train['Culmen Length (mm)'].min()))
print('평균 부리 길이 : {:.1f} (mm)'.format(df_train['Culmen Length (mm)'].mean()))
# Out:
# 가장 긴 부리 길이 : 55.1 (mm)
# 가장 짧은 부리 길이 : 33.5 (mm)
# 평균 부리 길이 : 44.6 (mm)

# %%
plt.figure(figsize=(7, 7))
plt.plot(df_train[['Culmen Length (mm)','Body Mass (g)']])
plt.show()

# %%
df_train[['Sex', 'Body Mass (g)']].groupby(['Sex'], as_index=False).mean().sort_values(by='Body Mass (g)', ascending=False)
# Out:
#       Sex  Body Mass (g)
# 1    MALE    4659.821429
# 0  FEMALE    4000.909091

# %%
df_train.head(10)
# Out:
#    id  ... Body Mass (g)
# 0   0  ...          5550
# 1   1  ...          3800
# 2   2  ...          4400
# 3   3  ...          4850
# 4   4  ...          5700
# 5   5  ...          5250
# 6   6  ...          4250
# 7   7  ...          3450
# 8   8  ...          3475
# 9   9  ...          4750
#
# [10 rows x 11 columns]

# %%
df_train[['Delta 15 N (o/oo)', 'Body Mass (g)']].groupby(['Delta 15 N (o/oo)'], as_index=False).mean().sort_values(by='Body Mass (g)', ascending=False)
# Out:
#      Delta 15 N (o/oo)  Body Mass (g)
# 28             8.27376           6300
# 39             8.40327           6000
# 9              8.08354           5850
# 53             8.59640           5800
# 38             8.38324           5700
# ..                 ...            ...
# 64             8.88098           3275
# 106            9.68950           3250
# 80             9.21510           3075
# 90             9.36392           3000
# 109            9.80589           2700
#
# [111 rows x 2 columns]

# %%
df_train[['Delta 13 C (o/oo)', 'Body Mass (g)']].groupby(['Delta 13 C (o/oo)'], as_index=False).mean().sort_values(by='Body Mass (g)', ascending=False)
# Out:
#      Delta 13 C (o/oo)  Body Mass (g)
# 83           -25.00169           6300
# 11           -26.76821           6000
# 42           -26.18161           5850
# 15           -26.71199           5800
# 5            -26.84272           5700
# ..                 ...            ...
# 57           -25.89741           3275
# 100          -24.43062           3250
# 39           -26.22530           3075
# 81           -25.01745           3000
# 85           -24.73735           2700
#
# [111 rows x 2 columns]

# %% [markdown]
# Gentoo penguin (Pygoscelis papua)== 0
# Chinstrap penguin (Pygoscelis antarctica) == 1
# Adelie Penguin (Pygoscelis adeliae) == 2

# %%
df_train['Species'].replace(['Gentoo penguin (Pygoscelis papua)','Chinstrap penguin (Pygoscelis antarctica)', 'Adelie Penguin (Pygoscelis adeliae)'],[0,1,2],inplace=True)
df_test['Species'].replace(['Gentoo penguin (Pygoscelis papua)','Chinstrap penguin (Pygoscelis antarctica)', 'Adelie Penguin (Pygoscelis adeliae)'],[0,1,2],inplace=True)

# %%
df_train['Island'].replace(['Biscoe','Dream', 'Torgersen'],[0,1,2],inplace=True)
df_test['Island'].replace(['Biscoe','Dream', 'Torgersen'],[0,1,2],inplace=True)

# %%
df_train['Clutch Completion'].replace(['No','Yes'],[0,1],inplace=True)
df_test['Clutch Completion'].replace(['No','Yes'],[0,1],inplace=True)

# %%
df_train['Sex'].replace(['MALE','FEMALE'],[0,1],inplace=True)
df_test['Sex'].replace(['MALE','FEMALE'],[0,1],inplace=True)

# %%
df_train.head()
# Out:
#    id  Species  Island  ...  Delta 15 N (o/oo)  Delta 13 C (o/oo)  Body Mass (g)
# 0   0        0       0  ...            8.30515          -25.19017           5550
# 1   1        1       1  ...            9.63074          -24.34684           3800
# 2   2        0       0  ...            8.51951          -27.01854           4400
# 3   3        0       0  ...            8.20106          -26.16524           4850
# 4   4        0       0  ...            8.38324          -26.84272           5700
#
# [5 rows x 11 columns]

# %%
heatmap_data = df_train[['Body Mass (g)','Species', 'Island', 'Clutch Completion', 'Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)', 'Sex', 'Delta 15 N (o/oo)','Delta 13 C (o/oo)']] 

colormap = plt.cm.RdBu
plt.figure(figsize=(12, 10))
plt.title('Penguin Correlation of Features', y=1.05, size=15)
sns.heatmap(heatmap_data.astype(float).corr(), linewidths=0.1, vmax=1.0,
           square=True, cmap=colormap, linecolor='white', annot=True, annot_kws={"size": 16})

# %%
df_test.head(10)
# Out:
#    id  Species  Island  ...  Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)
# 0   0        1       1  ...  0.0            9.43146          -24.68440
# 1   1        0       0  ...  0.0            8.31180          -26.35425
# 2   2        2       1  ...  1.0            8.36936          -26.11199
# 3   3        1       1  ...  1.0            9.62357          -24.78984
# 4   4        2       0  ...  1.0            8.38404          -25.19837
# 5   5        1       1  ...  0.0            9.00642          -24.61867
# 6   6        0       0  ...  1.0            8.01979          -26.68311
# 7   7        0       0  ...  0.0            7.82080          -25.48025
# 8   8        0       0  ...  1.0            7.99184          -26.20538
# 9   9        2       0  ...  0.0            8.90027          -25.11609
#
# [10 rows x 10 columns]

# %%
df_train['Sex'].mean()
# Out:
# 0.4954954954954955

# %%
for col in df_test.columns:
    msg = 'column: {:>20}\t Percent of NaN value: {:.2f}%'.format(col, 100 * (df_test[col].isnull().sum() / df_test[col].shape[0]))
    print(msg)
# Out:
# column:                   id	 Percent of NaN value: 0.00%
# column:              Species	 Percent of NaN value: 0.00%
# column:               Island	 Percent of NaN value: 0.00%
# column:    Clutch Completion	 Percent of NaN value: 0.00%
# column:   Culmen Length (mm)	 Percent of NaN value: 0.00%
# column:    Culmen Depth (mm)	 Percent of NaN value: 0.00%
# column:  Flipper Length (mm)	 Percent of NaN value: 0.00%
# column:                  Sex	 Percent of NaN value: 2.63%
# column:    Delta 15 N (o/oo)	 Percent of NaN value: 3.95%
# column:    Delta 13 C (o/oo)	 Percent of NaN value: 3.51%

# %%
df_train['Flipper Length (mm)'].mean()
# Out:
# 203.05263157894737

# %%
#df_train[['Flipper Length (mm)', 'Body Mass (g)']].groupby(['Flipper Length (mm)'], as_index=False).mean().sort_values(by='Body Mass (g)', ascending=False)

# %%
df_train.loc[(df_train.Sex.isnull())&(df_train['Body Mass (g)'] > 4250),'Sex'] = 0
df_train.loc[(df_train.Sex.isnull())&(df_train['Body Mass (g)'] <= 4250),'Sex'] = 1

df_test.loc[(df_test.Sex.isnull())&(df_test['Flipper Length (mm)'] > 205),'Sex'] = 0
df_test.loc[(df_test.Sex.isnull())&(df_test['Flipper Length (mm)'] <= 205),'Sex'] = 1

# %%
for col in df_train.columns:
    msg = 'column: {:>20}\t Percent of NaN value: {:.2f}%'.format(col, 100 * (df_train[col].isnull().sum() / df_train[col].shape[0]))
    print(msg)
# Out:
# column:                   id	 Percent of NaN value: 0.00%
# column:              Species	 Percent of NaN value: 0.00%
# column:               Island	 Percent of NaN value: 0.00%
# column:    Clutch Completion	 Percent of NaN value: 0.00%
# column:   Culmen Length (mm)	 Percent of NaN value: 0.00%
# column:    Culmen Depth (mm)	 Percent of NaN value: 0.00%
# column:  Flipper Length (mm)	 Percent of NaN value: 0.00%
# column:                  Sex	 Percent of NaN value: 0.00%
# column:    Delta 15 N (o/oo)	 Percent of NaN value: 2.63%
# column:    Delta 13 C (o/oo)	 Percent of NaN value: 2.63%
# column:        Body Mass (g)	 Percent of NaN value: 0.00%

# %%
for col in df_test.columns:
    msg = 'column: {:>20}\t Percent of NaN value: {:.2f}%'.format(col, 100 * (df_test[col].isnull().sum() / df_test[col].shape[0]))
    print(msg)
# Out:
# column:                   id	 Percent of NaN value: 0.00%
# column:              Species	 Percent of NaN value: 0.00%
# column:               Island	 Percent of NaN value: 0.00%
# column:    Clutch Completion	 Percent of NaN value: 0.00%
# column:   Culmen Length (mm)	 Percent of NaN value: 0.00%
# column:    Culmen Depth (mm)	 Percent of NaN value: 0.00%
# column:  Flipper Length (mm)	 Percent of NaN value: 0.00%
# column:                  Sex	 Percent of NaN value: 0.00%
# column:    Delta 15 N (o/oo)	 Percent of NaN value: 3.95%
# column:    Delta 13 C (o/oo)	 Percent of NaN value: 3.51%

# %%
df_train['Body Mass (g)'].mean()
# Out:
# 4327.850877192983

# %%
df_train['Delta 15 N (o/oo)'].mean()
# Out:
# 8.73763414414414

# %%
df_test['Delta 15 N (o/oo)'].mean()
# Out:
# 8.731226347031962

# %%
df_train[['Delta 15 N (o/oo)', 'Body Mass (g)']].groupby(['Delta 15 N (o/oo)'], as_index=False).mean().sort_values(by='Body Mass (g)', ascending=False)
# Out:
#      Delta 15 N (o/oo)  Body Mass (g)
# 28             8.27376           6300
# 39             8.40327           6000
# 9              8.08354           5850
# 53             8.59640           5800
# 38             8.38324           5700
# ..                 ...            ...
# 64             8.88098           3275
# 106            9.68950           3250
# 80             9.21510           3075
# 90             9.36392           3000
# 109            9.80589           2700
#
# [111 rows x 2 columns]

# %%
df_test['Delta 13 C (o/oo)'].mean()
# Out:
# -25.667744681818192

# %%
df_train['Delta 13 C (o/oo)'].mean()
# Out:
# -25.723051081081067

# %%
df_train.loc[(df_train['Delta 15 N (o/oo)'].isnull()),'Delta 15 N (o/oo)'] = 8.73763414414414
df_test.loc[(df_test['Delta 15 N (o/oo)'].isnull()),'Delta 15 N (o/oo)'] = 8.731226347031962

df_train.loc[(df_train['Delta 13 C (o/oo)'].isnull()),'Delta 13 C (o/oo)'] = -25.723051081081067
df_test.loc[(df_test['Delta 13 C (o/oo)'].isnull()),'Delta 13 C (o/oo)'] = -25.667744681818192

# %%
for col in df_train.columns:
    msg = 'column: {:>20}\t Percent of NaN value: {:.2f}%'.format(col, 100 * (df_train[col].isnull().sum() / df_train[col].shape[0]))
    print(msg)
# Out:
# column:                   id	 Percent of NaN value: 0.00%
# column:              Species	 Percent of NaN value: 0.00%
# column:               Island	 Percent of NaN value: 0.00%
# column:    Clutch Completion	 Percent of NaN value: 0.00%
# column:   Culmen Length (mm)	 Percent of NaN value: 0.00%
# column:    Culmen Depth (mm)	 Percent of NaN value: 0.00%
# column:  Flipper Length (mm)	 Percent of NaN value: 0.00%
# column:                  Sex	 Percent of NaN value: 0.00%
# column:    Delta 15 N (o/oo)	 Percent of NaN value: 0.00%
# column:    Delta 13 C (o/oo)	 Percent of NaN value: 0.00%
# column:        Body Mass (g)	 Percent of NaN value: 0.00%

# %%
for col in df_test.columns:
    msg = 'column: {:>20}\t Percent of NaN value: {:.2f}%'.format(col, 100 * (df_test[col].isnull().sum() / df_test[col].shape[0]))
    print(msg)
# Out:
# column:                   id	 Percent of NaN value: 0.00%
# column:              Species	 Percent of NaN value: 0.00%
# column:               Island	 Percent of NaN value: 0.00%
# column:    Clutch Completion	 Percent of NaN value: 0.00%
# column:   Culmen Length (mm)	 Percent of NaN value: 0.00%
# column:    Culmen Depth (mm)	 Percent of NaN value: 0.00%
# column:  Flipper Length (mm)	 Percent of NaN value: 0.00%
# column:                  Sex	 Percent of NaN value: 0.00%
# column:    Delta 15 N (o/oo)	 Percent of NaN value: 0.00%
# column:    Delta 13 C (o/oo)	 Percent of NaN value: 0.00%

# %%
df_train = pd.get_dummies(df_train, columns=['Species'], prefix='Species')
df_test = pd.get_dummies(df_test, columns=['Species'], prefix='Species')

df_train = pd.get_dummies(df_train, columns=['Island'], prefix='Island')
df_test = pd.get_dummies(df_test, columns=['Island'], prefix='Island')

# %%
df_test.head()
# Out:
#    id  Clutch Completion  Culmen Length (mm)  ...  Island_0  Island_1  Island_2
# 0   0                  1                52.0  ...         0         1         0
# 1   1                  1                55.9  ...         1         0         0
# 2   2                  1                38.9  ...         0         1         0
# 3   3                  1                45.2  ...         0         1         0
# 4   4                  0                37.9  ...         1         0         0
#
# [5 rows x 14 columns]

# %%
df_train.drop(['id' ,'Clutch Completion'], axis=1, inplace=True)
df_test.drop(['id' ,'Clutch Completion'], axis=1, inplace=True)

# %%
#importing all the required ML packages
from sklearn.ensemble import RandomForestClassifier 
from sklearn import metrics 
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier

# %%
X_train = df_train.drop('Body Mass (g)', axis=1).values
target_label = df_train['Body Mass (g)'].values
X_test = df_test.values

# %%
X_tr, X_vld, y_tr, y_vld = train_test_split(X_train, target_label, test_size=0.3, random_state=0)

# %%
y_vld.shape
# Out:
# (35,)

# %%
model = RandomForestClassifier()
model.fit(X_tr, y_tr)
prediction = model.predict(X_vld)

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_val_score

alphas = [0,0.1,1,10,100]

for alpha in alphas:
    ridge = Ridge(alpha=alpha)
    
    neg_mse_scores = cross_val_score(ridge, X_train, target_label, scoring = 'neg_mean_squared_error', cv = 5)
    avg_rmse = np.mean(np.sqrt(-neg_mse_scores))
    print('alpha 값 ', alpha, '일때 평균 rmse :', np.round(avg_rmse,4))
# Out:
# alpha 값  0 일때 평균 rmse : 332.7851
# alpha 값  0.1 일때 평균 rmse : 330.3049
# alpha 값  1 일때 평균 rmse : 327.6708
# alpha 값  10 일때 평균 rmse : 338.8514
# alpha 값  100 일때 평균 rmse : 370.7757

# %%
ridge = Ridge(alpha=1)
ridge.fit(X_tr, y_tr)
sample_submission = pd.read_csv('drive/MyDrive/pangdataset/my_submission.csv')

sample_submission['Body Mass (g)'] = ridge.predict(X_test)

sample_submission.to_csv('drive/MyDrive/pangdataset/my_submissiona.csv', index=False)

# %%
'''def RMSE(true, pred):
    score = np.sqrt(np.mean(np.square(true-pred)))
    return score

RMSE(y_vld,prediction)'''
# Out:
# 'def RMSE(true, pred):\n    score = np.sqrt(np.mean(np.square(true-pred)))\n    return score\n\nRMSE(y_vld,prediction)'

# %%
submission = pd.read_csv('drive/MyDrive/pangdataset/sample_submission.csv')

# %%
prediction = model.predict(X_test)
submission['Body Mass (g)'] = prediction

# %%
submission.to_csv('drive/MyDrive/pangdataset/my_submission2.csv', index=False)
